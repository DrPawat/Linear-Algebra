# %%
import pandas as pd
import warnings 
warnings.filterwarnings('ignore')

# basic libraries
import os
import numpy as np
import pandas as pd
import re
import string
from collections import Counter
import time

#visulaization modules
import missingno as msno
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode
from plotly.subplots import make_subplots
import pandas_profiling as pp
from pywaffle import Waffle

# %matplotlib inline
init_notebook_mode(connected= True)

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn import svm, datasets
from sklearn.metrics import classification_report ,f1_score,precision_score,recall_score,roc_auc_score
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import classification_report, confusion_matrix, plot_roc_curve
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# loading data
data = pd.read_csv('hs_data.csv', delimiter = ',', encoding = 'utf-8')
data
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %%
#columns of the data
data.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
#shape of the data
data.shape
# Out:
# (5110, 12)

# %%
# take a shallow copy from my data 
df=data.copy()

# %%
fig=px.pie(df,values=df["stroke"].value_counts(),
           names=["Not strok","stroke"],title="<b>Percentage of People Having Strokes",
           hole=.5,
       color_discrete_sequence=px.colors.qualitative.Pastel1,template="plotly")
fig.update_layout(title_font_size=30)
fig.show()
# Out:
# <div>                            <div id="3f75b2f6-d769-4b22-909f-f20cf0f752b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f75b2f6-d769-4b22-909f-f20cf0f752b7")) {                    Plotly.newPlot(                        "3f75b2f6-d769-4b22-909f-f20cf0f752b7",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["Not strok","stroke"],"legendgroup":"","name":"","showlegend":true,"values":[4861,249],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0. ...

# %%
x = data.describe()
x.style.background_gradient(cmap = "YlGn")
# Out:
# <style type="text/css">
# #T_3d839_row0_col0 {
#   background-color: #fbfdce;
#   color: #000000;
# }
# #T_3d839_row0_col1, #T_3d839_row0_col2, #T_3d839_row0_col3, #T_3d839_row0_col4, #T_3d839_row0_col5, #T_3d839_row0_col6, #T_3d839_row7_col0 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_3d839_row1_col0 {
#   background-color: #77c679;
#   color: #000000;
# }
# #T_3d839_row1_col1, #T_3d839_row5_col1, #T_3d839_row5_col4 {
#   background-color: #feffe2;
#   color: #000000;
# }
# #T_3d839_row1_col2, #T_3d839_row1_col3, #T_3d839_row1_col6, #T_3d839_row2_col2, #T_3d839_row2_col3, #T_3d839_row2_col4, #T_3d839_row2_col5, #T_3d839_row2_col6, #T_3d839_row3_col0, #T_3d839_row3_col1, #T_3d839_row3_col2, #T_3d839_row3_col3, #T_3d839_row3_col4, #T_3d839_row3_col5, #T_3d839_row3_col6, #T_3d839_row4_col2, #T_3d839_row4_col3, #T_3d839_row4_col5, #T_3d839_row4_col6, #T_3d839_row5_col2, #T_3d839_row5_col3, #T_3d839_row5_col6, #T_3d839_row6_col2, #T_3d839_row6_col3, #T_3d839_row6_col6, #T_3d839_row7_col2, #T_3d839_row7_col3, #T_3d839_row7_col6 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_3d839_row1_col4, #T_3d839_row6_col1, #T_3d839_row6_col4 {
#   background-color: #feffe1;
#   color: #000000;
# }
# #T_3d839_row1_col5, #T_3d839_row2_col1, #T_3d839_row4_col1, #T_3d839_row4_col4, #T_3d839_row5_col5, #T_3d839_row6_col5 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# #T_3d839_row2_col0 {
#   background-color: #cbea9c;
#   color: #000000;
# }
# #T_3d839_row4_col0 {
#   background-color: #dbf1a4;
#   color: #000000;
# }
# #T_3d839_row5_col0 {
#   background-color: #75c578;
#   color: #000000;
# }
# #T_3d839_row6_col0 {
#   background-color: #238443;
#   color: #f1f1f1;
# }
# #T_3d839_row7_col1, #T_3d839_row7_col5 {
#   background-color: #feffdf;
#   color: #000000;
# }
# #T_3d839_row7_col4 {
#   background-color: #fcfed6;
#   color: #000000;
# }
# </style>
# <table id="T_3d839">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3d839_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_3d839_level0_col1" class="col_heading level0 col1" >age</th>
#       <th id="T_3d839_level0_col2" class="col_heading level0 col2" >hypertension</th>
#       <th id="T_3d839_level0_col3" class="col_heading level0 col3" >heart_disease</th>
#       <th id="T_3d839_level0_col4" class="col_heading level0 col4" >avg_glucose_level</th>
#       <th id="T_3d839_level0_col5" class="col_heading level0 col5" >bmi</th>
#       <th id="T_3d839_level0_col6" class="col_heading level0 col6" >stroke</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d839_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_3d839_row0_col0" class="data row0 col0" >5110.000000</td>
#       <td id="T_3d839_row0_col1" class="data row0 col1" >5110.000000</td>
#       <td id="T_3d839_row0_col2" class="data row0 col2" >5110.000000</td>
#       <td id="T_3d839_row0_col3" class="data row0 col3" >5110.000000</td>
#       <td id="T_3d839_row0_col4" class="data row0 col4" >5110.000000</td>
#       <td id="T_3d839_row0_col5" class="data row0 col5" >4909.000000</td>
#       <td id="T_3d839_row0_col6" class="data row0 col6" >5110.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3d839_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_3d839_row1_col0" class="data row1 col0" >36517.829354</td>
#       <td id="T_3d839_row1_col1" class="data row1 col1" >43.226614</td>
#       <td id="T_3d839_row1_col2" class="data row1 col2" >0.097456</td>
#       <td id="T_3d839_row1_col3" class="data row1 col3" >0.054012</td>
#       <td id="T_3d839_row1_col4" class="data row1 col4" >106.147677</td>
#       <td id="T_3d839_row1_col5" class="data row1 col5" >28.893237</td>
#       <td id="T_3d839_row1_col6" class="data row1 col6" >0.048728</td>
#     </tr>
#     <tr>
#       <th id="T_3d839_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_3d839_row2_col0" class="data row2 col0" >21161.721625</td>
#       <td id="T_3d839_row2_col1" class="data row2 col1" >22.612647</td>
#       <td id="T_3d839_row2_col2" class="data row2 col2" >0.296607</td>
#       <td id="T_3d839_row2_col3" class="data row2 col3" >0.226063</td>
#       <td id="T_3d839_row2_col4" class="data row2 col4" >45.283560</td>
#       <td id="T_3d839_row2_col5" class="data row2 col5" >7.854067</td>
#       <td id="T_3d839_row2_col6" class="data row2 col6" >0.215320</td>
#     </tr>
#     <tr>
#       <th id="T_3d839_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_3d839_row3_col0" class="data row3 col0" >67.000000</td>
#       <td id="T_3d839_row3_col1" class="data row3 col1" >0.080000</td>
#       <td id="T_3d839_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_3d839_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_3d839_row3_col4" class="data row3 col4" >55.120000</td>
#       <td id="T_3d839_row3_col5" class="data row3 col5" >10.300000</td>
#       <td id="T_3d839_row3_col6" class="data row3 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3d839_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_3d839_row4_col0" class="data row4 col0" >17741.250000</td>
#       <td id="T_3d839_row4_col1" class="data row4 col1" >25.000000</td>
#       <td id="T_3d839_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_3d839_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_3d839_row4_col4" class="data row4 col4" >77.245000</td>
#       <td id="T_3d839_row4_col5" class="data row4 col5" >23.500000</td>
#       <td id="T_3d839_row4_col6" class="data row4 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3d839_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_3d839_row5_col0" class="data row5 col0" >36932.000000</td>
#       <td id="T_3d839_row5_col1" class="data row5 col1" >45.000000</td>
#       <td id="T_3d839_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_3d839_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_3d839_row5_col4" class="data row5 col4" >91.885000</td>
#       <td id="T_3d839_row5_col5" class="data row5 col5" >28.100000</td>
#       <td id="T_3d839_row5_col6" class="data row5 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3d839_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_3d839_row6_col0" class="data row6 col0" >54682.000000</td>
#       <td id="T_3d839_row6_col1" class="data row6 col1" >61.000000</td>
#       <td id="T_3d839_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_3d839_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_3d839_row6_col4" class="data row6 col4" >114.090000</td>
#       <td id="T_3d839_row6_col5" class="data row6 col5" >33.100000</td>
#       <td id="T_3d839_row6_col6" class="data row6 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3d839_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_3d839_row7_col0" class="data row7 col0" >72940.000000</td>
#       <td id="T_3d839_row7_col1" class="data row7 col1" >82.000000</td>
#       <td id="T_3d839_row7_col2" class="data row7 col2" >1.000000</td>
#       <td id="T_3d839_row7_col3" class="data row7 col3" >1.000000</td>
#       <td id="T_3d839_row7_col4" class="data row7 col4" >271.740000</td>
#       <td id="T_3d839_row7_col5" class="data row7 col5" >97.600000</td>
#       <td id="T_3d839_row7_col6" class="data row7 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#correlation
data.corr()
# Out:
#                          id       age  hypertension  heart_disease  \
# id                 1.000000  0.003538      0.003550      -0.001296
# age                0.003538  1.000000      0.276398       0.263796
# hypertension       0.003550  0.276398      1.000000       0.108306
# heart_disease     -0.001296  0.263796      0.108306       1.000000
# avg_glucose_level  0.001092  0.238171      0.174474       0.161857
# bmi                0.003084  0.333398      0.167811       0.041357
# stroke             0.006388  0.245257      0.127904       0.134914
#
#                    avg_glucose_level       bmi    stroke
# id                          0.001092  0.003084  0.006388
# age                         0.238171  0.333398  0.245257
# hypertension                0.174474  0.167811  0.127904
# heart_disease               0.161857  0.041357  0.134914
# avg_glucose_level           1.000000  0.175502  0.131945
# bmi                         0.175502  1.000000  0.042374
# stroke                      0.131945  0.042374  1.000000

# %%
data.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
df2=data.copy()

# %%
df2["bmi"]
# Out:
# 0       36.6
# 1        NaN
# 2       32.5
# 3       34.4
# 4       24.0
#         ...
# 5105     NaN
# 5106    40.0
# 5107    30.6
# 5108    25.6
# 5109    26.2
# Name: bmi, Length: 5110, dtype: float64

# %%
#The distribution of the data of the column
plt.figure(figsize=(15,10))
sns.displot(data = df2, x = "bmi", kde = True)

# %%
#filling the missings randomly
fill_list = data["bmi"].dropna()
df2 = data["bmi"].fillna(pd.Series(np.random.choice(fill_list, size = len(data.index))))
df2
# Out:
# 0       36.6
# 1       25.5
# 2       32.5
# 3       34.4
# 4       24.0
#         ...
# 5105    16.2
# 5106    40.0
# 5107    30.6
# 5108    25.6
# 5109    26.2
# Name: bmi, Length: 5110, dtype: float64

# %%
df2.isnull().sum()
# Out:
# 0

# %%
#checking the distribution after filling the missing values randomly
sns.displot(df2, kde = True, color = "Purple")

# %%
#filling with the mean
df3 = data["bmi"].fillna(data["bmi"].mean())
df3
# Out:
# 0       36.600000
# 1       28.893237
# 2       32.500000
# 3       34.400000
# 4       24.000000
#           ...
# 5105    28.893237
# 5106    40.000000
# 5107    30.600000
# 5108    25.600000
# 5109    26.200000
# Name: bmi, Length: 5110, dtype: float64

# %%
#checking the distribution after filling the missing values with the mean
sns.displot(df3, kde = True, color = "Purple")

# %%
#filling the missing randomly
data["bmi"] = df2
data.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21  25.5     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
data.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
data.smoking_status.value_counts()
# Out:
# never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: smoking_status, dtype: int64

# %%
data['smoking_status'] = data['smoking_status'].replace(['Unknown'],np.nan)

# %%
data.isnull().sum()
# Out:
# id                      0
# gender                  0
# age                     0
# hypertension            0
# heart_disease           0
# ever_married            0
# work_type               0
# Residence_type          0
# avg_glucose_level       0
# bmi                     0
# smoking_status       1544
# stroke                  0
# dtype: int64

# %%
#The distribution of the data of the column
plt.figure(figsize=(12,10))
sns.countplot(data = data, x = "smoking_status",palette='PuBuGn')
# Out:
# <AxesSubplot:xlabel='smoking_status', ylabel='count'>

# %%
#filling the missings randomly
fill_list = data["smoking_status"].dropna()
df4 = data["smoking_status"].fillna(pd.Series(np.random.choice(fill_list, size = len(data.index))))
df4.head
# Out:
# <bound method NDFrame.head of 0       formerly smoked
# 1          never smoked
# 2          never smoked
# 3                smokes
# 4          never smoked
#              ...
# 5105       never smoked
# 5106       never smoked
# 5107       never smoked
# 5108    formerly smoked
# 5109    formerly smoked
# Name: smoking_status, Length: 5110, dtype: object>

# %%
df4.isnull().sum()
# Out:
# 0

# %%
#checking the distribution after filling the missing values randomly
plt.figure(figsize=(12,10))
sns.countplot( x=df4,palette='cubehelix')
# Out:
# <AxesSubplot:xlabel='smoking_status', ylabel='count'>

# %%
sns.set(rc = {'figure.figsize':(6,4)})
sns.stripplot(y="age", x ="stroke", data = data)
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='age'>

# %%
sns.stripplot(y="avg_glucose_level", x ="stroke", data = data, palette='cubehelix')
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='avg_glucose_level'>

# %%
sns.stripplot(y="bmi", x ="stroke", data = data, palette='rocket')
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='bmi'>

# %%
data = data.loc[(data["bmi"]<70)]
data.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21  25.5     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
#re-checking for the outliers
sns.stripplot(y="bmi", x ="stroke", data = data, palette='viridis')
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='bmi'>

# %%
data = data.loc[(data["gender"] == "Male") | (data["gender"] == "Female") ]
data.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21  25.5     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
gender_le = LabelEncoder()
data["gender"] = gender_le.fit_transform(data["gender"])

# %%
data.gender.value_counts()
# Out:
# 0    2993
# 1    2112
# Name: gender, dtype: int64

# %%
evermarried_le = LabelEncoder()
data["ever_married"] = evermarried_le.fit_transform(data["ever_married"])

# %%
data.ever_married.value_counts()
# Out:
# 1    3351
# 0    1754
# Name: ever_married, dtype: int64

# %%
worktype_le = LabelEncoder()
data["work_type"] = worktype_le.fit_transform(data["work_type"])

# %%
data.work_type.value_counts()
# Out:
# 2    2920
# 3     819
# 4     687
# 0     657
# 1      22
# Name: work_type, dtype: int64

# %%
residencetype_le = LabelEncoder()
data["Residence_type"] = residencetype_le.fit_transform(data["Residence_type"])

# %%
data.Residence_type.value_counts()
# Out:
# 1    2595
# 0    2510
# Name: Residence_type, dtype: int64

# %%
smoking_status_le = LabelEncoder()
data["smoking_status"] = smoking_status_le.fit_transform(data["smoking_status"])

# %%
data.smoking_status.value_counts()
# Out:
# 1    1890
# 3    1543
# 0     884
# 2     788
# Name: smoking_status, dtype: int64

# %%
data.head()
# Out:
#       id  gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0   9046       1  67.0             0              1             1          2
# 1  51676       0  61.0             0              0             1          3
# 2  31112       1  80.0             0              1             1          2
# 3  60182       0  49.0             0              0             1          2
# 4   1665       0  79.0             1              0             1          3
#
#    Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# 0               1             228.69  36.6               0       1
# 1               0             202.21  25.5               1       1
# 2               0             105.92  32.5               1       1
# 3               1             171.23  34.4               2       1
# 4               0             174.12  24.0               1       1

# %%
plt.figure(figsize=(12,12))
sns.heatmap(data.corr(),annot=True,cmap="BuPu")
# Out:
# <AxesSubplot:>

# %%
#Making a copy from the column that needs to be scaled
stroke_scale = data.iloc[:, :-1]
stroke_scale.reset_index()
norm_scaler = MinMaxScaler()
stroke_scale = norm_scaler.fit_transform(stroke_scale.to_numpy())
stroke_scale = pd.DataFrame (stroke_scale, columns = ["id", "gender", "age", "hypertension", "heart_disease", "ever_married", "work_type", "Residence_type", "avg_glucose_level", "bmi", "smoking_status"])
stroke_scale.head()
# Out:
#          id  gender       age  hypertension  heart_disease  ever_married  \
# 0  0.123214     1.0  0.816895           0.0            1.0           1.0
# 1  0.708205     0.0  0.743652           0.0            0.0           1.0
# 2  0.426015     1.0  0.975586           0.0            1.0           1.0
# 3  0.824928     0.0  0.597168           0.0            0.0           1.0
# 4  0.021929     0.0  0.963379           1.0            0.0           1.0
#
#    work_type  Residence_type  avg_glucose_level       bmi  smoking_status
# 0       0.50             1.0           0.801265  0.465487        0.000000
# 1       0.75             0.0           0.679023  0.269027        0.333333
# 2       0.50             0.0           0.234512  0.392920        0.333333
# 3       0.50             1.0           0.536008  0.426549        0.666667
# 4       0.75             0.0           0.549349  0.242478        0.333333

# %%
data.iloc[:, : -1] = stroke_scale
data.head()
# Out:
#          id  gender       age  hypertension  heart_disease  ever_married  \
# 0  0.123214     1.0  0.816895           0.0            1.0           1.0
# 1  0.708205     0.0  0.743652           0.0            0.0           1.0
# 2  0.426015     1.0  0.975586           0.0            1.0           1.0
# 3  0.824928     0.0  0.597168           0.0            0.0           1.0
# 4  0.021929     0.0  0.963379           1.0            0.0           1.0
#
#    work_type  Residence_type  avg_glucose_level       bmi  smoking_status  \
# 0       0.50             1.0           0.801265  0.465487        0.000000
# 1       0.75             0.0           0.679023  0.269027        0.333333
# 2       0.50             0.0           0.234512  0.392920        0.333333
# 3       0.50             1.0           0.536008  0.426549        0.666667
# 4       0.75             0.0           0.549349  0.242478        0.333333
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
data.isnull().sum()
# Out:
# id                   5
# gender               5
# age                  5
# hypertension         5
# heart_disease        5
# ever_married         5
# work_type            5
# Residence_type       5
# avg_glucose_level    5
# bmi                  5
# smoking_status       5
# stroke               0
# dtype: int64

# %%
#filling that missing value that appeared after scaling
data["age"].fillna(data["age"].mode()[0], inplace = True)
data["avg_glucose_level"].fillna(data["avg_glucose_level"].mode()[0], inplace = True)
data["bmi"].fillna(data["bmi"].mode()[0], inplace = True)

# %%
data.isnull().sum()
# Out:
# id                   5
# gender               5
# age                  0
# hypertension         5
# heart_disease        5
# ever_married         5
# work_type            5
# Residence_type       5
# avg_glucose_level    0
# bmi                  0
# smoking_status       5
# stroke               0
# dtype: int64

# %%
#correlation
x = data.corr()
x.style.background_gradient(cmap = "rocket")
# Out:
# <style type="text/css">
# #T_9d2b2_row0_col0, #T_9d2b2_row1_col1, #T_9d2b2_row2_col2, #T_9d2b2_row3_col3, #T_9d2b2_row4_col4, #T_9d2b2_row5_col5, #T_9d2b2_row6_col6, #T_9d2b2_row7_col7, #T_9d2b2_row8_col8, #T_9d2b2_row9_col9, #T_9d2b2_row10_col10, #T_9d2b2_row11_col11 {
#   background-color: #faebdd;
#   color: #000000;
# }
# #T_9d2b2_row0_col1, #T_9d2b2_row5_col0, #T_9d2b2_row6_col4, #T_9d2b2_row6_col11 {
#   background-color: #0d0a21;
#   color: #f1f1f1;
# }
# #T_9d2b2_row0_col2, #T_9d2b2_row7_col10 {
#   background-color: #6b1f56;
#   color: #f1f1f1;
# }
# #T_9d2b2_row0_col3 {
#   background-color: #2d1738;
#   color: #f1f1f1;
# }
# #T_9d2b2_row0_col4 {
#   background-color: #170f28;
#   color: #f1f1f1;
# }
# #T_9d2b2_row0_col5, #T_9d2b2_row8_col3 {
#   background-color: #691f55;
#   color: #f1f1f1;
# }
# #T_9d2b2_row0_col6 {
#   background-color: #631f53;
#   color: #f1f1f1;
# }
# #T_9d2b2_row0_col7, #T_9d2b2_row5_col6 {
#   background-color: #04051a;
#   color: #f1f1f1;
# }
# #T_9d2b2_row0_col8 {
#   background-color: #221331;
#   color: #f1f1f1;
# }
# #T_9d2b2_row0_col9, #T_9d2b2_row7_col9 {
#   background-color: #591e50;
#   color: #f1f1f1;
# }
# #T_9d2b2_row0_col10, #T_9d2b2_row7_col6 {
#   background-color: #641f54;
#   color: #f1f1f1;
# }
# #T_9d2b2_row0_col11, #T_9d2b2_row6_col3, #T_9d2b2_row10_col1 {
#   background-color: #1a102a;
#   color: #f1f1f1;
# }
# #T_9d2b2_row1_col0, #T_9d2b2_row2_col0, #T_9d2b2_row2_col7, #T_9d2b2_row3_col0, #T_9d2b2_row8_col0, #T_9d2b2_row9_col0, #T_9d2b2_row11_col7 {
#   background-color: #08081e;
#   color: #f1f1f1;
# }
# #T_9d2b2_row1_col2 {
#   background-color: #611f53;
#   color: #f1f1f1;
# }
# #T_9d2b2_row1_col3 {
#   background-color: #33183c;
#   color: #f1f1f1;
# }
# #T_9d2b2_row1_col4 {
#   background-color: #35193e;
#   color: #f1f1f1;
# }
# #T_9d2b2_row1_col5, #T_9d2b2_row9_col3 {
#   background-color: #5c1e51;
#   color: #f1f1f1;
# }
# #T_9d2b2_row1_col6 {
#   background-color: #781f59;
#   color: #f1f1f1;
# }
# #T_9d2b2_row1_col7, #T_9d2b2_row2_col1, #T_9d2b2_row2_col6, #T_9d2b2_row2_col10, #T_9d2b2_row3_col7, #T_9d2b2_row5_col1, #T_9d2b2_row6_col0, #T_9d2b2_row6_col5, #T_9d2b2_row6_col7, #T_9d2b2_row6_col9, #T_9d2b2_row8_col7, #T_9d2b2_row9_col1, #T_9d2b2_row10_col0, #T_9d2b2_row10_col2, #T_9d2b2_row10_col3, #T_9d2b2_row10_col4, #T_9d2b2_row10_col8, #T_9d2b2_row10_col11 {
#   background-color: #03051a;
#   color: #f1f1f1;
# }
# #T_9d2b2_row1_col8 {
#   background-color: #34193d;
#   color: #f1f1f1;
# }
# #T_9d2b2_row1_col9, #T_9d2b2_row11_col8 {
#   background-color: #501d4c;
#   color: #f1f1f1;
# }
# #T_9d2b2_row1_col10, #T_9d2b2_row2_col8 {
#   background-color: #761f58;
#   color: #f1f1f1;
# }
# #T_9d2b2_row1_col11 {
#   background-color: #1b112b;
#   color: #f1f1f1;
# }
# #T_9d2b2_row2_col3, #T_9d2b2_row8_col9 {
#   background-color: #901d5b;
#   color: #f1f1f1;
# }
# #T_9d2b2_row2_col4 {
#   background-color: #7a1f59;
#   color: #f1f1f1;
# }
# #T_9d2b2_row2_col5 {
#   background-color: #f58d64;
#   color: #f1f1f1;
# }
# #T_9d2b2_row2_col9 {
#   background-color: #c21753;
#   color: #f1f1f1;
# }
# #T_9d2b2_row2_col11 {
#   background-color: #711f57;
#   color: #f1f1f1;
# }
# #T_9d2b2_row3_col1 {
#   background-color: #130d25;
#   color: #f1f1f1;
# }
# #T_9d2b2_row3_col2, #T_9d2b2_row6_col10 {
#   background-color: #c11754;
#   color: #f1f1f1;
# }
# #T_9d2b2_row3_col4, #T_9d2b2_row5_col11 {
#   background-color: #3d1a42;
#   color: #f1f1f1;
# }
# #T_9d2b2_row3_col5 {
#   background-color: #9a1b5b;
#   color: #f1f1f1;
# }
# #T_9d2b2_row3_col6, #T_9d2b2_row5_col8, #T_9d2b2_row8_col6, #T_9d2b2_row11_col3 {
#   background-color: #581e4f;
#   color: #f1f1f1;
# }
# #T_9d2b2_row3_col8 {
#   background-color: #601f52;
#   color: #f1f1f1;
# }
# #T_9d2b2_row3_col9 {
#   background-color: #861e5b;
#   color: #f1f1f1;
# }
# #T_9d2b2_row3_col10 {
#   background-color: #431c46;
#   color: #f1f1f1;
# }
# #T_9d2b2_row3_col11 {
#   background-color: #451c47;
#   color: #f1f1f1;
# }
# #T_9d2b2_row4_col0, #T_9d2b2_row7_col0 {
#   background-color: #07071d;
#   color: #f1f1f1;
# }
# #T_9d2b2_row4_col1 {
#   background-color: #2a1636;
#   color: #f1f1f1;
# }
# #T_9d2b2_row4_col2 {
#   background-color: #bd1655;
#   color: #f1f1f1;
# }
# #T_9d2b2_row4_col3, #T_9d2b2_row8_col4 {
#   background-color: #511e4d;
#   color: #f1f1f1;
# }
# #T_9d2b2_row4_col5 {
#   background-color: #891e5b;
#   color: #f1f1f1;
# }
# #T_9d2b2_row4_col6, #T_9d2b2_row9_col8, #T_9d2b2_row11_col6 {
#   background-color: #5e1f52;
#   color: #f1f1f1;
# }
# #T_9d2b2_row4_col7, #T_9d2b2_row6_col2, #T_9d2b2_row9_col7 {
#   background-color: #05061b;
#   color: #f1f1f1;
# }
# #T_9d2b2_row4_col8 {
#   background-color: #5b1e51;
#   color: #f1f1f1;
# }
# #T_9d2b2_row4_col9, #T_9d2b2_row5_col3 {
#   background-color: #661f54;
#   color: #f1f1f1;
# }
# #T_9d2b2_row4_col10, #T_9d2b2_row11_col10 {
#   background-color: #561e4f;
#   color: #f1f1f1;
# }
# #T_9d2b2_row4_col11 {
#   background-color: #481c48;
#   color: #f1f1f1;
# }
# #T_9d2b2_row5_col2 {
#   background-color: #f58f66;
#   color: #f1f1f1;
# }
# #T_9d2b2_row5_col4 {
#   background-color: #401b44;
#   color: #f1f1f1;
# }
# #T_9d2b2_row5_col7, #T_9d2b2_row10_col7 {
#   background-color: #06071c;
#   color: #f1f1f1;
# }
# #T_9d2b2_row5_col9 {
#   background-color: #c51852;
#   color: #f1f1f1;
# }
# #T_9d2b2_row5_col10, #T_9d2b2_row10_col9 {
#   background-color: #140e26;
#   color: #f1f1f1;
# }
# #T_9d2b2_row6_col1, #T_9d2b2_row7_col8, #T_9d2b2_row8_col1 {
#   background-color: #20122e;
#   color: #f1f1f1;
# }
# #T_9d2b2_row6_col8 {
#   background-color: #100b23;
#   color: #f1f1f1;
# }
# #T_9d2b2_row7_col1, #T_9d2b2_row11_col0 {
#   background-color: #0a091f;
#   color: #f1f1f1;
# }
# #T_9d2b2_row7_col2 {
#   background-color: #6e1f57;
#   color: #f1f1f1;
# }
# #T_9d2b2_row7_col3, #T_9d2b2_row9_col10, #T_9d2b2_row9_col11 {
#   background-color: #281535;
#   color: #f1f1f1;
# }
# #T_9d2b2_row7_col4 {
#   background-color: #180f29;
#   color: #f1f1f1;
# }
# #T_9d2b2_row7_col5, #T_9d2b2_row11_col9 {
#   background-color: #681f55;
#   color: #f1f1f1;
# }
# #T_9d2b2_row7_col11 {
#   background-color: #1d112c;
#   color: #f1f1f1;
# }
# #T_9d2b2_row8_col2 {
#   background-color: #b41658;
#   color: #f1f1f1;
# }
# #T_9d2b2_row8_col5 {
#   background-color: #971c5b;
#   color: #f1f1f1;
# }
# #T_9d2b2_row8_col10 {
#   background-color: #4c1d4b;
#   color: #f1f1f1;
# }
# #T_9d2b2_row8_col11, #T_9d2b2_row11_col4 {
#   background-color: #461c48;
#   color: #f1f1f1;
# }
# #T_9d2b2_row9_col2 {
#   background-color: #ce1d4e;
#   color: #f1f1f1;
# }
# #T_9d2b2_row9_col4 {
#   background-color: #271534;
#   color: #f1f1f1;
# }
# #T_9d2b2_row9_col5 {
#   background-color: #cd1c4e;
#   color: #f1f1f1;
# }
# #T_9d2b2_row9_col6 {
#   background-color: #110c24;
#   color: #f1f1f1;
# }
# #T_9d2b2_row10_col5, #T_9d2b2_row11_col1 {
#   background-color: #0e0b22;
#   color: #f1f1f1;
# }
# #T_9d2b2_row10_col6 {
#   background-color: #bf1654;
#   color: #f1f1f1;
# }
# #T_9d2b2_row11_col2 {
#   background-color: #b71657;
#   color: #f1f1f1;
# }
# #T_9d2b2_row11_col5 {
#   background-color: #871e5b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9d2b2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d2b2_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_9d2b2_level0_col1" class="col_heading level0 col1" >gender</th>
#       <th id="T_9d2b2_level0_col2" class="col_heading level0 col2" >age</th>
#       <th id="T_9d2b2_level0_col3" class="col_heading level0 col3" >hypertension</th>
#       <th id="T_9d2b2_level0_col4" class="col_heading level0 col4" >heart_disease</th>
#       <th id="T_9d2b2_level0_col5" class="col_heading level0 col5" >ever_married</th>
#       <th id="T_9d2b2_level0_col6" class="col_heading level0 col6" >work_type</th>
#       <th id="T_9d2b2_level0_col7" class="col_heading level0 col7" >Residence_type</th>
#       <th id="T_9d2b2_level0_col8" class="col_heading level0 col8" >avg_glucose_level</th>
#       <th id="T_9d2b2_level0_col9" class="col_heading level0 col9" >bmi</th>
#       <th id="T_9d2b2_level0_col10" class="col_heading level0 col10" >smoking_status</th>
#       <th id="T_9d2b2_level0_col11" class="col_heading level0 col11" >stroke</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d2b2_level0_row0" class="row_heading level0 row0" >id</th>
#       <td id="T_9d2b2_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_9d2b2_row0_col1" class="data row0 col1" >0.002175</td>
#       <td id="T_9d2b2_row0_col2" class="data

# %%
data = data.loc[:, ["age", "hypertension", "heart_disease", "avg_glucose_level","bmi", "ever_married", "stroke"]]
data.head()
# Out:
#         age  hypertension  heart_disease  avg_glucose_level       bmi  \
# 0  0.816895           0.0            1.0           0.801265  0.465487
# 1  0.743652           0.0            0.0           0.679023  0.269027
# 2  0.975586           0.0            1.0           0.234512  0.392920
# 3  0.597168           0.0            0.0           0.536008  0.426549
# 4  0.963379           1.0            0.0           0.549349  0.242478
#
#    ever_married  stroke
# 0           1.0       1
# 1           1.0       1
# 2           1.0       1
# 3           1.0       1
# 4           1.0       1

# %%
data["stroke"].value_counts()
# Out:
# 0    4856
# 1     249
# Name: stroke, dtype: int64

# %%
class1 = data.loc[(data["stroke"]==1)]
class1.head()
# Out:
#         age  hypertension  heart_disease  avg_glucose_level       bmi  \
# 0  0.816895           0.0            1.0           0.801265  0.465487
# 1  0.743652           0.0            0.0           0.679023  0.269027
# 2  0.975586           0.0            1.0           0.234512  0.392920
# 3  0.597168           0.0            0.0           0.536008  0.426549
# 4  0.963379           1.0            0.0           0.549349  0.242478
#
#    ever_married  stroke
# 0           1.0       1
# 1           1.0       1
# 2           1.0       1
# 3           1.0       1
# 4           1.0       1

# %%
class0 = data.loc[(data["stroke"]==0)]
class0.head()
# Out:
#           age  hypertension  heart_disease  avg_glucose_level       bmi  \
# 249  0.035645           0.0            0.0           0.184655  0.136283
# 250  0.707031           1.0            0.0           0.151602  0.511504
# 251  0.096680           0.0            0.0           0.257455  0.129204
# 252  0.853516           0.0            0.0           0.064260  0.453097
# 253  0.169922           0.0            0.0           0.490075  0.155752
#
#      ever_married  stroke
# 249           0.0       0
# 250           1.0       0
# 251           0.0       0
# 252           1.0       0
# 253           0.0       0

# %%
class1_over = class1.sample(data["stroke"].value_counts()[0], replace=True)
test_over = pd.concat([class1_over, class0], axis=0)
test_over.head()
# Out:
#           age  hypertension  heart_disease  avg_glucose_level       bmi  \
# 80   0.719238           0.0            0.0           0.189456  0.598230
# 158  0.865723           0.0            0.0           0.649017  0.421239
# 190  0.792480           0.0            0.0           0.695457  0.631858
# 157  0.694824           0.0            0.0           0.769874  0.477876
# 50   0.926758           0.0            0.0           0.160835  0.398230
#
#      ever_married  stroke
# 80            1.0       1
# 158           1.0       1
# 190           1.0       1
# 157           1.0       1
# 50            0.0       1

# %%
test_over["stroke"].value_counts()
# Out:
# 1    4856
# 0    4856
# Name: stroke, dtype: int64

# %%
data = test_over.copy().reset_index()
data.head()
# Out:
#    index       age  hypertension  heart_disease  avg_glucose_level       bmi  \
# 0     80  0.719238           0.0            0.0           0.189456  0.598230
# 1    158  0.865723           0.0            0.0           0.649017  0.421239
# 2    190  0.792480           0.0            0.0           0.695457  0.631858
# 3    157  0.694824           0.0            0.0           0.769874  0.477876
# 4     50  0.926758           0.0            0.0           0.160835  0.398230
#
#    ever_married  stroke
# 0           1.0       1
# 1           1.0       1
# 2           1.0       1
# 3           1.0       1
# 4           0.0       1

# %%
plt.figure(figsize= (8, 6))
data_pie  = [4856 , 4856]
labels = ["No", "yes"]
explode = [0.1, 0]
plt.pie(data_pie ,labels= labels , explode = explode , autopct="%1.2f%%", shadow= True, colors= ['#aaffee', '#ffaaee'])
plt.legend()
plt.show()

# %%
data=data.dropna()

# %%
X = data.drop(['stroke','index'], axis= 1).values 
y = data['stroke'].values

# %%
X.shape
# Out:
# (9707, 6)

# %%
y.shape
# Out:
# (9707,)

# %%
X_train , X_test , y_train , y_test = train_test_split(X,y, test_size= 0.20, random_state =42,shuffle=True)

# %%
X_train.shape
# Out:
# (7765, 6)

# %%
y_train.shape
# Out:
# (7765,)

# %%
lr = LogisticRegression()
#Training the model
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
#The score of the training process
lr_train_score = lr.score(X_train, y_train)
lr_train_score
# Out:
# 0.7729555698647779

# %%
#The score of the testing process
lr_test_score = lr.score(X_test, y_test)
lr_test_score
# Out:
# 0.7718846549948507

# %%
lr_y_pred = lr.predict(X_test)
df_out = pd.DataFrame({"y_test":y_test, "y_pred": lr_y_pred})
df_out.head()
# Out:
#    y_test  y_pred
# 0       1       0
# 1       1       1
# 2       0       0
# 3       0       0
# 4       0       0

# %%
plt.figure(figsize=(12,7))
plt.plot(df_out[:50])
plt.gca().get_lines()[0].set_color("green")
plt.gca().get_lines()[1].set_color("purple")
plt.legend(["Actual", "Predicted"])

# %%
#confusion matrix
plot_confusion_matrix(confusion_matrix(y_test, lr_y_pred), cmap = "viridis_r")
# Out:
# (<Figure size 600x400 with 1 Axes>,
#  <AxesSubplot:xlabel='predicted label', ylabel='true label'>)

# %%
lr_ac_score=roc_auc_score(y_test, lr_y_pred)
lr_f1_score=f1_score(y_test, lr_y_pred)
lr_prc_score=precision_score(y_test, lr_y_pred)
lr_rec_score=recall_score(y_test, lr_y_pred)

print('Roc ACU Score :',lr_ac_score)
print('F1_Score :',lr_f1_score)
print('Precesion',lr_prc_score)
print('Recall',lr_rec_score)
# Out:
# Roc ACU Score : 0.7704644320499631
# F1_Score : 0.7865060240963855
# Precesion 0.7611940298507462
# Recall 0.8135593220338984

# %%
#AUC
plot_roc_curve(lr, X_test, y_test)

# %%
knn = KNeighborsClassifier()

# %%
params = {'n_neighbors': [2, 3, 4, 5, 6, 7]}
grid = GridSearchCV(knn, params, cv=10, scoring='accuracy', return_train_score=False,verbose=1)
grid.fit(X_train, y_train)
print(grid.best_params_)
# Out:
# Fitting 10 folds for each of 6 candidates, totalling 60 fits
# {'n_neighbors': 2}

# %%
knn = KNeighborsClassifier(n_neighbors = 2)
#Training the model
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
#The score of the training process
knn_train_score = knn.score(X_train, y_train)
knn_train_score
# Out:
# 1.0

# %%
#The score of the testing process
knn_test_score = knn.score(X_test, y_test)
knn_test_score
# Out:
# 0.9727085478887745

# %%
knn_y_pred = knn.predict(X_test)
df_out = pd.DataFrame({"y_test":y_test, "y_pred": knn_y_pred})
df_out.head()
# Out:
#    y_test  y_pred
# 0       1       1
# 1       1       1
# 2       0       0
# 3       0       0
# 4       0       0

# %%
plt.figure(figsize=(10,6))
plt.plot(df_out[:50])
plt.gca().get_lines()[0].set_color("green")
plt.gca().get_lines()[1].set_color("pink")
plt.legend(["Actual", "Predicted"])

# %%
#confusion matrix
plot_confusion_matrix(confusion_matrix(y_test, knn_y_pred), cmap = "Greens")
# Out:
# (<Figure size 600x400 with 1 Axes>,
#  <AxesSubplot:xlabel='predicted label', ylabel='true label'>)

# %%
knn_ac_score=roc_auc_score(y_test, knn_y_pred)
knn_f1_score=f1_score(y_test, knn_y_pred)
knn_prc_score=precision_score(y_test, knn_y_pred)
knn_rec_score=recall_score(y_test, knn_y_pred)

print('Roc ACU Score :',knn_ac_score)
print('F1_Score :',knn_f1_score)
print('Precesion',knn_prc_score)
print('Recall',knn_rec_score)
# Out:
# Roc ACU Score : 0.9717784877529286
# F1_Score : 0.9742593491986402
# Precesion 0.9498106060606061
# Recall 1.0

# %%
#AUC
plot_roc_curve(knn, X_test, y_test, color = "purple")

# %%
dt = DecisionTreeClassifier()

# %%
params = {'max_depth': list(range(4, 23)), "max_features" : [2,3,4,5,6]}
grid = GridSearchCV(dt, params, cv=10, scoring='accuracy', return_train_score=False,verbose=1)
grid.fit(X_train, y_train)
print(grid.best_params_)
# Out:
# Fitting 10 folds for each of 95 candidates, totalling 950 fits
# {'max_depth': 22, 'max_features': 2}

# %%
dt = DecisionTreeClassifier(max_depth = 21, max_features = 3)
#Training the model
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=21, max_features=3)

# %%
#The score of the training process
dt_train_score = dt.score(X_train, y_train)
dt_train_score
# Out:
# 0.9931745009658725

# %%
#The score of the testing process
dt_test_score = dt.score(X_test, y_test)
dt_test_score
# Out:
# 0.9711637487126673

# %%
dt_y_pred = dt.predict(X_test)
df_out = pd.DataFrame({"y_test":y_test, "y_pred": dt_y_pred})
df_out.head()
# Out:
#    y_test  y_pred
# 0       1       1
# 1       1       1
# 2       0       0
# 3       0       0
# 4       0       0

# %%
plt.figure(figsize=(10,6))
plt.plot(df_out[:50])
plt.gca().get_lines()[0].set_color("red")
plt.gca().get_lines()[1].set_color("black")
plt.legend(["Actual", "Predicted"])

# %%
#confusion matrix
plot_confusion_matrix(confusion_matrix(y_test, dt_y_pred))
# Out:
# (<Figure size 600x400 with 1 Axes>,
#  <AxesSubplot:xlabel='predicted label', ylabel='true label'>)

# %%
dt_ac_score=roc_auc_score(y_test, dt_y_pred)
dt_f1_score=f1_score(y_test, dt_y_pred)
dt_prc_score=precision_score(y_test, dt_y_pred)
dt_rec_score=recall_score(y_test, dt_y_pred)

print('Roc ACU Score :',dt_ac_score)
print('F1_Score :',dt_f1_score)
print('Precesion',dt_prc_score)
print('Recall',dt_rec_score)
# Out:
# Roc ACU Score : 0.9701810436634718
# F1_Score : 0.9728419010669254
# Precesion 0.947119924457035
# Recall 1.0

# %%
#AUC
plot_roc_curve(dt, X_test, y_test, color = "red")

# %%
params = {'max_depth': list(range(6,16)), "max_features" : [2,3,4,5,6]}
grid = GridSearchCV(RandomForestClassifier(random_state = 42), params, cv=10, scoring='accuracy', return_train_score=False,verbose=1)
grid.fit(X_train, y_train)
print(grid.best_params_)
# Out:
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [94], line 3
#       1 params = {'max_depth': list(range(6,16)), "max_features" : [2,3,4,5,6]}
#       2 grid = GridSearchCV(RandomForestClassifier(random_state = 42), params, cv=10, scoring='accuracy', return_train_score=False,verbose=1)
# ----> 3 grid.fit(X_train, y_train)
#       4 print(grid.best_params_)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_search.py:875, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     869     results = self._format_results(
#     870         all_candidate_params, n_splits, all_out, all_more_results
#     871     )
#     873     return results
# --> 875 self._run_search(evaluate_candidates)
#     877 # multimetric is determined here because in the case of a callable
#     878 # self.scoring the return type is only known after calling
#     879 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_search.py:1379, in GridSearchCV._run_search(self, evaluate_candidates)
#    1377 def _run_search(self, evaluate_candidates):
#    1378     """Search all candidates in param_grid"""
# -> 1379     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_search.py:822, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     814 if self.verbose > 0:
#     815     print(
#     816         "Fitting {0} folds for each of {1} candidates,"
#     817         " totalling {2} fits".format(
#     818             n_splits, n_candidates, n_candidates * n_splits
#     819         )
#     820     )
# --> 822 out = parallel(
#     823     delayed(_fit_and_score)(
#     824         clone(base_estimator),
#     825         X,
#     826         y,
#     827         train=train,
#     828         test=test,
#     829         parameters=parameters,
#     830         split_progress=(split_idx, n_splits),
#     831         candidate_progress=(cand_idx, n_candidates),
#     832         **fit_and_score_kwargs,
#     833     )
#     834     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     835         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     836     )
#     837 )
#     839 if len(out) < 1:
#     840     raise ValueError(
#     841         "No fits were performed. "
#     842         "Was the CV iterator empty? "
#     843         "Were there no candidates?"
#     844     )
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\fixes.py:117, in _FuncWrapper.__call__(self, *args, **kwargs)
#     115 def __call__(self, *args, **kwargs):
#     116     with config_context(**self.config):
# --> 117         return self.function(*args, **kwargs)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:686, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684         estimator.fit(X_train, **fit_params)
#     685     else:
# --> 686         estimator.fit(X_train, y_train, **fit_params)
#     688 except Exception:
#     689     # Note fit time as time until error
#     690     fit_time = time.time() - start_time
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_forest.py:476, in BaseForest.fit(self, X, y, sample_weight)
#     465 trees = [
#     466     self._make_estimator(append=False, random_state=random_state)
#     467     for i in range(n_more_estimators)
#     468 ]
#     470 # Parallel loop: we prefer the threading backend as the Cython code
#     471 # for fitting the trees is internally releasing the Python GIL
#     472 # making threading more efficient than multiprocessing in
#     473 # that case. However, for joblib 0.12+ we respect any
#     474 # parallel_backend contexts set at a higher level,
#     475 # since correctness does not rely on using threads.
# --> 476 trees = Parallel(
#     477     n_jobs=self.n_jobs,
#     478     verbose=self.verbose,
#     479     prefer="threads",
#     480 )(
#     481     delayed(_parallel_build_trees)(
#     482         t,
#     483         self.bootstrap,
#     484         X,
#     485         y,
#     486         sample_weight,
#     487         i,
#     488         len(trees),
#     489         verbose=self.verbose,
#     490         class_weight=self.class_weight,
#     491         n_samples_bootstrap=n_samples_bootstrap,
#     492     )
#     493     for i, t in enumerate(trees)
#     494 )
#     496 # Collect newly grown trees
#     497 self.estimators_.extend(trees)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\fixes.py:117, in _FuncWrapper.__call__(self, *args, **kwargs)
#     115 def __call__(self, *args, **kwargs):
#     116     with config_context(**self.config):
# --> 117         return self.function(*args, **kwargs)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_forest.py:189, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     186     elif class_weight == "balanced_subsample":
#     187         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 189     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     190 else:
#     191     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\tree\_classes.py:969, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     939 def fit(self, X, y, sample_weight=None, check_input=True):
#     940     """Build a decision tree classifier from the training set (X, y).
#     941
#     942     Parameters
#    (...)
#     966         Fitted estimator.
#     967     """
# --> 969     super().fit(
#     970         X,
#     971         y,
#     972         sample_weight=sample_weight,
#     973         check_input=check_input,
#     974     )
#     975     return self
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\tree\_classes.py:458, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     447 else:
#     448     builder = BestFirstTreeBuilder(
#     449         splitter,
#     450         min_samples_split,
#    (...)
#     455         self.min_impurity_decrease,
#     456     )
# --> 458 builder.build(self.tree_, X, y, sample_weight)
#     460 if self.n_outputs_ == 1 and is_classifier(self):
#     461     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:
